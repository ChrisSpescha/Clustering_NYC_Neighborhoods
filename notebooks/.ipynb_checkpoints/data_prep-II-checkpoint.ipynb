# %%
import pandas as pd
import requests
import json
import numpy as np

# %% [markdown]
# -----
# added from git saved
# ---

# %% [markdown]
# def getNearbyVenues(names, latitudes, longitudes, radius=1500):
#
#     venues_list=[]
#     for name, lat, lng in zip(names, latitudes, longitudes):
#         print(name)
#
#         # create the API request URL
#         url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
#             CLIENT_ID,
#             CLIENT_SECRET,
#             VERSION,
#             lat,
#             lng,
#             radius,
#             LIMIT)
#
#         # make the GET request
#         results = requests.get(url).json()["response"]['groups'][0]['items']
#
#         # return only relevant information for each nearby venue
#         venues_list.append([(
#             name,
#             lat,
#             lng,
#             v['venue']['name'],
#             v['venue']['location']['lat'],
#             v['venue']['location']['lng'],
#             v['venue']['categories'][0]['name']) for v in results])
#
#     nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
#     nearby_venues.columns = ['Neighborhood',
#                   'Neighborhood Latitude',
#                   'Neighborhood Longitude',
#                   'Venue',
#                   'Venue Latitude',
#                   'Venue Longitude',
#                   'Venue Category']
#
#     return(nearby_venues)

# %% [markdown]
# -----
# added from git saved
# ---

# %% [markdown]
# #### Parse 'nyc_geo.json' into Dataframe

# %%
f = open('../data/nyc_geo.json')
data = json.load(f)

# %%
bk_neighboorhoods = {}

# %%
# will parse only brooklyn to reduce scope of project
count = 0 
for i in data['features']:
        bk_neighboorhoods[count] = { 
                                                      'latitude': i['geometry']['coordinates'][1],
                                                      'longitude': i['geometry']['coordinates'][0],
                                                      'neighborhood': i['properties']['name']
                                                     }
        count += 1

# %%
df = pd.DataFrame.from_dict(bk_neighboorhoods).T

# %%
df.head(2)
# Out:
#     latitude  longitude neighborhood
# 0  40.894705 -73.847201    Wakefield
# 1  40.874294 -73.829939   Co-op City

# %%
df.latitude.max()
# Out:
# 40.90854282950666

# %%
df['latitude'] = pd.to_numeric(df['latitude'])

# %%
def neighborhood_classifier(lat):
    # print(lat)
    neighbor = df[df['latitude'] < lat]['latitude'].idxmax()
    return df.iloc[neighbor]['neighborhood']

# %% [markdown]
# ---

# %% [markdown]
# #### Loading brooklyn housing data

# %%
housing_df = pd.read_csv('../data/nyc_housing_prices_jul_2020.csv')
brooklyn_housing_data = housing_df[housing_df['borough'] == 'brooklyn']
brooklyn_housing_data.shape
# Out:
# (22, 6)

# %%
# brooklyn_housing_data.rename(columns={'neigborhood': 'neighborhood'}, inplace=True)

# %%
merged_df = df.merge(brooklyn_housing_data, how='inner', on='neighborhood')

# %%
merged_df.head(2)
# Out:
#     latitude  longitude neighborhood   borough  studio 1_bedroom 2_bedroom  \
# 0  40.645103 -74.010316  Sunset Park  brooklyn  $1,400    $1,912    $2,300
# 1  40.730201 -73.954241   Greenpoint  brooklyn  $2,347    $2,812    $3,708
#
#   3_bedroom
# 0    $2,500
# 1    $5,278

# %% [markdown]
# ---

# %% [markdown]
# #### Google places API data (restaurants)

# %%
API_KEY = 'AIzaSyDIR1htuqa4Pctefq6f7JpH3--bmm5dZHg'

# %%
resp = requests.get(f'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.730201%2C-73.954241&radius=1500&type=restaurant&key={API_KEY}')

# %%
len(resp.json()['results'])
# Out:
# 20

# %%
def get_restaruant_count(lat, long):
    resp = requests.get(f'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={lat}%2C{long}&radius=1500&type=restaurant&key={API_KEY}')
    return len(resp.json()['results'])

# %%
df['restaruant_count'] = df.apply(lambda x: get_restaruant_count(x.latitude, x.longitude), axis=1)

# %% [markdown]
# #### Squirrel Data

# %%
squirrel_df = pd.read_csv('../data/extra/2018_Central_Park_Squirrel_Census_-_Squirrel_Data.csv')

# %%
# squirrel_df = squirrel_df[['X', 'Y', 'Shift', 'Age', 'Primary Fur Color', 'Location', 'Lat/Long']]

# %%
squirrel_df.columns
# Out:
# Index(['X', 'Y', 'Unique Squirrel ID', 'Hectare', 'Shift', 'Date',
#        'Hectare Squirrel Number', 'Age', 'Primary Fur Color',
#        'Highlight Fur Color', 'Combination of Primary and Highlight Color',
#        'Color notes', 'Location', 'Above Ground Sighter Measurement',
#        'Specific Location', 'Running', 'Chasing', 'Climbing', 'Eating',
#        'Foraging', 'Other Activities', 'Kuks', 'Quaas', 'Moans', 'Tail flags',
#        'Tail twitches', 'Approaches', 'Indifferent', 'Runs from',
#        'Other Interactions', 'Lat/Long', 'Zip Codes', 'Community Districts',
#        'Borough Boundaries', 'City Council Districts', 'Police Precincts'],
#       dtype='object')

# %%
sdf = squirrel_df.drop(['Unique Squirrel ID', 'Hectare', 'Date', 'Highlight Fur Color','Above Ground Sighter Measurement',
       'Specific Location', 'Combination of Primary and Highlight Color', 'Color notes', 'Zip Codes', 'Community Districts',
       'Borough Boundaries', 'City Council Districts', 'Police Precincts'], axis=1)

# %%
sdf.columns
# Out:
# Index(['X', 'Y', 'Shift', 'Hectare Squirrel Number', 'Age',
#        'Primary Fur Color', 'Location', 'Running', 'Chasing', 'Climbing',
#        'Eating', 'Foraging', 'Other Activities', 'Kuks', 'Quaas', 'Moans',
#        'Tail flags', 'Tail twitches', 'Approaches', 'Indifferent', 'Runs from',
#        'Other Interactions', 'Lat/Long'],
#       dtype='object')

# %%
sfd.drop([''])

# %% [markdown]
# -------------------------------------

# %%
# squirrel_df['neighborhood'] = squirrel_df.apply(lambda x: neighborhood_classifier(x.Y), axis=1)

# %%
type(squirrel_df.iloc[0].X)
# Out:
# numpy.float64

# %% [markdown]
# #### RideShare Data

# %%
rideshare = pd.read_csv('other-Lyft_B02510.csv')
# rideshare.dropna(inplace=True)
# rideshare.head(2)
# rideshare = rideshare[['start_lat', 'start_lng']]

# %%
rideshare.head()
# Out:
#       time_of_trip  start_lat  start_lng Unnamed: 3
# 0    9/4/2014 9:51   40.64705  -73.77988        NaN
# 1  8/27/2014 21:13   40.74916  -73.98373        NaN
# 2   9/4/2014 14:16   40.64065  -73.97594        NaN
# 3   9/4/2014 16:08   40.75002  -73.99514        NaN
# 4   8/28/2014 2:41   40.76715  -73.98636        NaN

# %%
rideshare = rideshare[rideshare['start_lat'] < 40.908542]
rideshare = rideshare[rideshare['start_lat'] > 40.505333]

# %%
rideshare['start_lat'] = pd.to_numeric(rideshare.start_lat)

# %%
rideshare.dtypes
# Out:
# time_of_trip     object
# start_lat       float64
# start_lng       float64
# Unnamed: 3       object
# dtype: object

# %%
rideshare['neighborhood'] = rideshare.apply(lambda x: neighborhood_classifier(x.start_lat), axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21384\1735272219.py in <module>
# ----> 1 rideshare['neighborhood'] = rideshare.apply(lambda x: neighborhood_classifier(x.start_lat), axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8846             kwargs=kwargs,
#    8847         )
# -> 8848         return op.apply().__finalize__(self, method="apply")
#    8849
#    8850     def applymap(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#     731             return self.apply_raw()
#     732
# --> 733         return self.apply_standard()
#     734
#     735     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     855
#     856     def apply_standard(self):
# --> 857         results, res_index = self.apply_series_generator()
#     858
#     859         # wrap results
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     871             for i, v in enumerate(series_gen):
#     872                 # ignore SettingWithCopy here in case the user mutates
# --> 873                 results[i] = self.f(v)
#     874                 if isinstance(results[i], ABCSeries):
#     875                     # If we have a view on v, we need to make a copy because
#
# ~\AppData\Local\Temp\ipykernel_21384\1735272219.py in <lambda>(x)
# ----> 1 rideshare['neighborhood'] = rideshare.apply(lambda x: neighborhood_classifier(x.start_lat), axis=1)
#
# ~\AppData\Local\Temp\ipykernel_21384\3559457852.py in neighborhood_classifier(lat)
#       1 def neighborhood_classifier(lat):
#       2     # print(lat)
# ----> 3     neighbor = df[df['latitude'] < lat]['latitude'].idxmax()
#       4     return df.iloc[neighbor]['neighborhood']
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in idxmax(self, axis, skipna, *args, **kwargs)
#    2402         nan
#    2403         """
# -> 2404         i = self.argmax(axis, skipna, *args, **kwargs)
#    2405         if i == -1:
#    2406             return np.nan
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in argmax(self, axis, skipna, *args, **kwargs)
#     655             # error: Incompatible return value type (got "Union[int, ndarray]", expected
#     656             # "int")
# --> 657             return nanops.nanargmax(  # type: ignore[return-value]
#     658                 delegate, skipna=skipna
#     659             )
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      86             if any(self.check(obj) for obj in obj_iter):
#      87                 f_name = f.__name__.replace("nan", "")
# ---> 88                 raise TypeError(
#      89                     f"reduction operation '{f_name}' not allowed for this dtype"
#      90                 )
#
# TypeError: reduction operation 'argmax' not allowed for this dtype

# %%
rideshare
# Out:
# 0         40.64705
# 1         40.74916
# 2         40.64065
# 3         40.75002
# 4         40.76715
#             ...
# 267696    40.71931
# 267697    40.73868
# 267698    40.71554
# 267699    40.74667
# 267700    40.74393
# Name: start_lat, Length: 267661, dtype: float64

# %%
ride_count = pd.DataFrame(rideshare.neighborhood.value_counts())
ride_count.reset_index(inplace=True)
ride_count.rename(columns={'neighborhood': 'ride_count'}, inplace=True)
ride_count.rename(columns={'index': 'neighborhood'}, inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# #### Air Quality Data

# %%
air_df = pd.read_csv('../data/extra/Air_Quality.csv')

# %%
air_df
# Out:
#        Unique ID  Indicator ID                  Name Measure Measure Info  \
# 0         216498           386            Ozone (O3)    Mean          ppb
# 1         216499           386            Ozone (O3)    Mean          ppb
# 2         219969           386            Ozone (O3)    Mean          ppb
# 3         219970           386            Ozone (O3)    Mean          ppb
# 4         164876           383  Sulfur Dioxide (SO2)    Mean          ppb
# ...          ...           ...                   ...     ...          ...
# 16117     671118           386            Ozone (O3)    Mean          ppb
# 16118     671119           386            Ozone (O3)    Mean          ppb
# 16119     671120           386            Ozone (O3)    Mean          ppb
# 16120     671121           386            Ozone (O3)    Mean          ppb
# 16121     671122           386            Ozone (O3)    Mean          ppb
#
#       Geo Type Name  Geo Join ID                          Geo Place Name  \
# 0                CD          313                     Coney Island (CD13)
# 1                CD          313                     Coney Island (CD13)
# 2           Borough            1                                   Bronx
# 3           Borough            1                                   Bronx
# 4                CD          211        Morris Park and Bronxdale (CD11)
# ...             ...          ...                                     ...
# 16117            CD          306    Park Slope and Carroll Gardens (CD6)
# 16118            CD          305   East New York and Starrett City (CD5)
# 16119            CD          304                          Bushwick (CD4)
# 16120            CD          303                Bedford Stuyvesant (CD3)
# 16121            CD          302  Fort Greene and Brooklyn Heights (CD2)
#
#           Time Period  Start_Date  Data Value  Message
# 0         Summer 2013  06/01/2013       34.64      NaN
# 1         Summer 2014  06/01/2014       33.22      NaN
# 2         Summer 2013  06/01/2013       31.25      NaN
# 3         Summer 2014  06/01/2014       31.15      NaN
# 4      Winter 2008-09  12/01/2008        5.89      NaN
# ...               ...         ...         ...      ...
# 16117     Summer 2020  06/01/2020       28.70      NaN
# 16118     Summer 2020  06/01/2020       29.56      NaN
# 16119     Summer 2020  06/01/2020       29.65      NaN
# 16120     Summer 2020  06/01/2020       29.28      NaN
# 16121     Summer 2020  06/01/2020       28.93      NaN
#
# [16122 rows x 12 columns]

# %%
air_df['Start_Date'] = pd.to_datetime(air_df['Start_Date'])

# %%
air_df = air_df[air_df['Start_Date'] > '2020-05-01']

# %%
air_df.Name.value_counts()
# Out:
# Ozone (O3)                         141
# Nitrogen Dioxide (NO2)             141
# Fine Particulate Matter (PM2.5)    141
# Name: Name, dtype: int64

# %%
m
# Out:
#      latitude  longitude   neighborhood
# 0   40.625801 -74.030621      Bay Ridge
# 1   40.611009  -73.99518    Bensonhurst
# 2   40.645103 -74.010316    Sunset Park
# 3   40.730201 -73.954241     Greenpoint
# 4   40.595260 -73.973471      Gravesend
# ..        ...        ...            ...
# 65  40.703176 -73.988753          Dumbo
# 66  40.598525 -73.959185      Homecrest
# 67  40.681999 -73.890346  Highland Park
# 68  40.609378 -73.948415        Madison
# 69  40.646926 -73.948177        Erasmus
#
# [70 rows x 3 columns]

# %%
air_df
# Out:
#        Unique ID  Indicator ID                    Name Measure Measure Info  \
# 13772     670936           386              Ozone (O3)    Mean          ppb
# 13961     670937           386              Ozone (O3)    Mean          ppb
# 15139     667029           375  Nitrogen Dioxide (NO2)    Mean          ppb
# 15142     667035           375  Nitrogen Dioxide (NO2)    Mean          ppb
# 15145     667041           375  Nitrogen Dioxide (NO2)    Mean          ppb
# ...          ...           ...                     ...     ...          ...
# 16117     671118           386              Ozone (O3)    Mean          ppb
# 16118     671119           386              Ozone (O3)    Mean          ppb
# 16119     671120           386              Ozone (O3)    Mean          ppb
# 16120     671121           386              Ozone (O3)    Mean          ppb
# 16121     671122           386              Ozone (O3)    Mean          ppb
#
#       Geo Type Name  Geo Join ID                          Geo Place Name  \
# 13772         UHF34          102                         Northeast Bronx
# 13961         UHF34          101                 Kingsbridge - Riverdale
# 15139       Borough            1                                   Bronx
# 15142       Borough            2                                Brooklyn
# 15145       Borough            3                               Manhattan
# ...             ...          ...                                     ...
# 16117            CD          306    Park Slope and Carroll Gardens (CD6)
# 16118            CD          305   East New York and Starrett City (CD5)
# 16119            CD          304                          Bushwick (CD4)
# 16120            CD          303                Bedford Stuyvesant (CD3)
# 16121            CD          302  Fort Greene and Brooklyn Heights (CD2)
#
#        Time Period Start_Date  Data Value  Message
# 13772  Summer 2020 2020-06-01       30.85      NaN
# 13961  Summer 2020 2020-06-01       28.49      NaN
# 15139  Summer 2020 2020-06-01       13.16      NaN
# 15142  Summer 2020 2020-06-01       10.82      NaN
# 15145  Summer 2020 2020-06-01       15.97      NaN
# ...            ...        ...         ...      ...
# 16117  Summer 2020 2020-06-01       28.70      NaN
# 16118  Summer 2020 2020-06-01       29.56      NaN
# 16119  Summer 2020 2020-06-01       29.65      NaN
# 16120  Summer 2020 2020-06-01       29.28      NaN
# 16121  Summer 2020 2020-06-01       28.93      NaN
#
# [423 rows x 12 columns]

# %% [markdown]
# #### Merged DF

# %%
new_df = merged_df.merge(ride_count, how='inner', on='neighborhood')

# %%
new_df['studio'] = new_df['studio'].str[1:]
new_df['1_bedroom'] = new_df['1_bedroom'].str[1:]
new_df['2_bedroom'] = new_df['2_bedroom'].str[1:]
new_df['3_bedroom'] = new_df['3_bedroom'].str[1:]

# %%
new_df['studio'] = new_df['studio'].str.extract('(\d+)', expand=False)

# %%
new_df
# Out:
#      latitude  longitude               neighborhood   borough studio  \
# 0   40.645103 -74.010316                Sunset Park  brooklyn      1
# 1   40.670829 -73.943291              Crown Heights  brooklyn      1
# 2   40.642382 -73.980421                 Kensington  brooklyn      1
# 3   40.656946 -73.980073            Windsor Terrace  brooklyn      1
# 4   40.676822 -73.964859           Prospect Heights  brooklyn      2
# 5   40.707144 -73.958115               Williamsburg  brooklyn      2
# 6   40.698116 -73.925258                   Bushwick  brooklyn      2
# 7   40.695864 -73.993782           Brooklyn Heights  brooklyn      2
# 8   40.687920 -73.998561                Cobble Hill  brooklyn      2
# 9   40.680540 -73.994654            Carroll Gardens  brooklyn      2
# 10  40.676253 -74.012759                   Red Hook  brooklyn    NaN
# 11  40.673931 -73.994441                    Gowanus  brooklyn      2
# 12  40.688527 -73.972906                Fort Greene  brooklyn      2
# 13  40.672321  -73.97705                 Park Slope  brooklyn      2
# 14  40.693229 -73.967843               Clinton Hill  brooklyn      2
# 15  40.685683 -73.983748                Boerum Hill  brooklyn      2
# 16  40.658420 -73.954899  Prospect Lefferts Gardens  brooklyn      1
#
#    1_bedroom 2_bedroom 3_bedroom  ride_count
# 0     $1,912    $2,300    $2,500        1240
# 1     $2,310    $2,582    $3,185        1606
# 2     $1,866    $2,925    $3,215         484
# 3     $2,563    $2,877    $3,679         452
# 4     $2,823    $3,621    $4,320        1270
# 5     $3,166    $4,043    $5,081        2864
# 6     $2,373    $2,749    $2,851        4873
# 7     $3,270    $5,983    $8,654        2250
# 8     $2,734    $4,222    $6,122         673
# 9     $2,634    $3,914    $5,027        1356
# 10    $2,300    $4,287         -         656
# 11    $2,796    $3,588    $3,687        1080
# 12    $2,508    $4,213    $6,760        2938
# 13    $2,739    $3,422    $4,883        1602
# 14    $2,776    $3,450    $4,204        3017
# 15    $2,854    $4,356    $4,921        1947
# 16    $2,094    $2,911    $3,423        1064
