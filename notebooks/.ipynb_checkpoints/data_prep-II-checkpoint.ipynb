# %%
import pandas as pd
import requests
import json

# %%
f = open('../data/nyc_geo.json')
data = json.load(f)

# %%
bk_neighboorhoods = {}

# %%
for i in data['features']:
    bk_neighboorhoods[i['properties']['name']] = {'latitude': i['geometry']['coordinates'][0],
                                                  'longitude': i['geometry']['coordinates'][1],
                                                  'borough': i['properties']['borough']
                                                 }

# %%
bk_neighboorhoods
# Out:
# {'Wakefield': {'latitude': -73.84720052054902,
#   'longitude': 40.89470517661,
#   'borough': 'Bronx'},
#  'Co-op City': {'latitude': -73.82993910812398,
#   'longitude': 40.87429419303012,
#   'borough': 'Bronx'},
#  'Eastchester': {'latitude': -73.82780644716412,
#   'longitude': 40.887555677350775,
#   'borough': 'Bronx'},
#  'Fieldston': {'latitude': -73.90564259591682,
#   'longitude': 40.89543742690383,
#   'borough': 'Bronx'},
#  'Riverdale': {'latitude': -73.9125854610857,
#   'longitude': 40.890834493891305,
#   'borough': 'Bronx'},
#  'Kingsbridge': {'latitude': -73.90281798724604,
#   'longitude': 40.88168737120521,
#   'borough': 'Bronx'},
#  'Marble Hill': {'latitude': -73.91065965862981,
#   'longitude': 40.87655077879964,
#   'borough': 'Manhattan'},
#  'Woodlawn': {'latitude': -73.86731496814176,
#   'longitude': 40.89827261213805,
#   'borough': 'Bronx'},
#  'Norwood': {'latitude': -73.8793907395681,
#   'longitude': 40.87722415599446,
#   'borough': 'Bronx'},
# ...

# %%
new = pd.DataFrame.from_dict(data['features'])

# %%
new
# Out:
#         type                  id  \
# 0    Feature    nyu_2451_34572.1
# 1    Feature    nyu_2451_34572.2
# 2    Feature    nyu_2451_34572.3
# 3    Feature    nyu_2451_34572.4
# 4    Feature    nyu_2451_34572.5
# ..       ...                 ...
# 301  Feature  nyu_2451_34572.302
# 302  Feature  nyu_2451_34572.303
# 303  Feature  nyu_2451_34572.304
# 304  Feature  nyu_2451_34572.305
# 305  Feature  nyu_2451_34572.306
#
#                                               geometry geometry_name  \
# 0    {'type': 'Point', 'coordinates': [-73.84720052...          geom
# 1    {'type': 'Point', 'coordinates': [-73.82993910...          geom
# 2    {'type': 'Point', 'coordinates': [-73.82780644...          geom
# 3    {'type': 'Point', 'coordinates': [-73.90564259...          geom
# 4    {'type': 'Point', 'coordinates': [-73.91258546...          geom
# ..                                                 ...           ...
# 301  {'type': 'Point', 'coordinates': [-74.00011136...          geom
# ...

# %%
housing_df = pd.read_csv('../data/nyc_housing_prices_jul_2020.csv')
brooklyn_housing_data = housing_df[housing_df['borough'] == 'brooklyn']
brooklyn_housing_data.head(2)
# Out:
#      borough         neigborhood  studio 1_bedroom 2_bedroom 3_bedroom
# 33  brooklyn  Bedford-Stuyvesant  $2,044    $2,297    $2,611    $3,214
# 34  brooklyn         Boerum Hill  $2,092    $2,854    $4,356    $4,921

# %%
API_KEY = 'AIzaSyDIR1htuqa4Pctefq6f7JpH3--bmm5dZHg'

# %%
resp = requests.get(f'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-33.8670522,151.1957362&radius=500&types=food&name=harbour&key={API_KEY}')

# %%
resp.json()
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -33.8660355, 'lng': 151.2012092},
#     'viewport': {'northeast': {'lat': -33.86468567010728,
#       'lng': 151.2025590298927},
#      'southwest': {'lat': -33.86738532989272, 'lng': 151.1998593701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Harbour Bar & Restaurant',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3200,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110120720524925804190">A Google User</a>'],
# ...
